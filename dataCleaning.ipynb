# %%
import pandas as pd
import numpy as np

#pd.set_option("display.max_rows", None)

# %%
gender_path = "D:/MCIT/CIS 5500 Databases/WebApp/P_Data_Extract_From_Gender_Statistics.xlsx"
health_path = "D:/MCIT/CIS 5500 Databases/WebApp/P_Data_Extract_From_Health_Nutrition_and_Population_Statistics.xlsx"
jobs_path = "D:/MCIT/CIS 5500 Databases/WebApp/P_Data_Extract_From_Jobs.xlsx"

# %%
gender = pd.read_excel(gender_path)

# %%
gender.head()
# Out:
#                                          Series Name     Series Code  \
# 0  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 1  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 2  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 3  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 4  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
#
#                   Country Name Country Code 2008 [YR2008] 2009 [YR2009]  \
# 0                  Afghanistan          AFG             0             0
# 1  Africa Eastern and Southern          AFE            ..            ..
# 2   Africa Western and Central          AFW            ..            ..
# 3                      Albania          ALB             1             1
# 4                      Algeria          DZA             1             1
#
#   2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# ...

# %%
gender.tail()
# Out:
#                                   Series Name Series Code Country Name  \
# 262615                                    NaN         NaN          NaN
# 262616                                    NaN         NaN          NaN
# 262617                                    NaN         NaN          NaN
# 262618  Data from database: Gender Statistics         NaN          NaN
# 262619               Last Updated: 01/31/2023         NaN          NaN
#
#        Country Code 2008 [YR2008] 2009 [YR2009] 2010 [YR2010] 2011 [YR2011]  \
# 262615          NaN           NaN           NaN           NaN           NaN
# 262616          NaN           NaN           NaN           NaN           NaN
# 262617          NaN           NaN           NaN           NaN           NaN
# 262618          NaN           NaN           NaN           NaN           NaN
# 262619          NaN           NaN           NaN           NaN           NaN
#
#        2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]
# ...

# %%
gender = gender.drop([262615, 262616, 262617, 262618, 262619])
gender = gender.replace("..", "NULL")

# %%
gender.tail()
# Out:
#                                               Series Name       Series Code  \
# 262610  Youth illiterate population, 15-24 years, male...  UIS_LP_AG15T24_M
# 262611  Youth illiterate population, 15-24 years, male...  UIS_LP_AG15T24_M
# 262612  Youth illiterate population, 15-24 years, male...  UIS_LP_AG15T24_M
# 262613  Youth illiterate population, 15-24 years, male...  UIS_LP_AG15T24_M
# 262614  Youth illiterate population, 15-24 years, male...  UIS_LP_AG15T24_M
#
#               Country Name Country Code 2008 [YR2008] 2009 [YR2009]  \
# 262610  West Bank and Gaza          PSE          3042          3312
# 262611               World          WLD      50271169      50574608
# 262612         Yemen, Rep.          YEM          NULL          NULL
# 262613              Zambia          ZMB          NULL          NULL
# 262614            Zimbabwe          ZWE          NULL          NULL
#
#        2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# ...

# %%
gender.isna().any().any()
# Out:
# False

# %%
health = pd.read_excel(health_path)

# %%
health.head()
# Out:
#                                          Series Name     Series Code  \
# 0  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 1  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 2  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 3  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 4  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
#
#   Country Name Country Code 2008 [YR2008] 2009 [YR2009] 2010 [YR2010]  \
# 0  Afghanistan          AFG            ..            ..            ..
# 1      Belgium          BEL            ..            ..            ..
# 2   Bangladesh          BGD            ..            ..            ..
# 3       Bhutan          BTN          34.9            ..          33.5
# 4      Austria          AUT            ..            ..            ..
#
#   2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
health.tail()
# Out:
#                                               Series Name Series Code  \
# 105868                                                NaN         NaN
# 105869                                                NaN         NaN
# 105870                                                NaN         NaN
# 105871  Data from database: Health Nutrition and Popul...         NaN
# 105872                           Last Updated: 12/23/2022         NaN
#
#        Country Name Country Code 2008 [YR2008] 2009 [YR2009] 2010 [YR2010]  \
# 105868          NaN          NaN           NaN           NaN           NaN
# 105869          NaN          NaN           NaN           NaN           NaN
# 105870          NaN          NaN           NaN           NaN           NaN
# 105871          NaN          NaN           NaN           NaN           NaN
# 105872          NaN          NaN           NaN           NaN           NaN
#
#        2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# ...

# %%
health = health.drop([105868, 105869, 105870, 105871, 105872])
health = health.replace("..", "NULL")

# %%
health.tail()
# Out:
#                                          Series Name        Series Code  \
# 105863  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105864  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105865  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105866  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105867  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
#
#               Country Name Country Code 2008 [YR2008] 2009 [YR2009]  \
# 105863  West Bank and Gaza          PSE         60722       62009.5
# 105864               World          WLD          NULL          NULL
# 105865         Yemen, Rep.          YEM      397553.5      404589.5
# 105866              Zambia          ZMB        260300      266607.5
# 105867            Zimbabwe          ZWE        209359      217235.5
#
#        2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# ...

# %%
gender_countries = gender["Country Name"].unique()
health_countries = health["Country Name"].unique()

# %%
countries = set(gender_countries.tolist() + health_countries.tolist())
countries
# Out:
# {'Afghanistan',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
# ...

# %%
gender = gender.rename(columns = {"2008 [YR2008]" : "2008", 
                                  "2009 [YR2009]" : "2009", 
                                  "2010 [YR2010]" : "2010", 
                                  "2011 [YR2011]" : "2011", 
                                  "2012 [YR2012]" : "2012", 
                                  "2013 [YR2013]" : "2013",
                                  "2014 [YR2014]" : "2014", 
                                  "2015 [YR2015]" : "2015", 
                                  "2016 [YR2016]" : "2016"})

# %%
gender.head()
# Out:
#                                          Series Name     Series Code  \
# 0  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 1  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 2  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 3  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
# 4  A woman can apply for a passport in the same w...  SG_APL_PSPT_EQ
#
#                   Country Name Country Code  2008  2009  2010  2011  2012  \
# 0                  Afghanistan          AFG     0     0     0     0     0
# 1  Africa Eastern and Southern          AFE  NULL  NULL  NULL  NULL  NULL
# 2   Africa Western and Central          AFW  NULL  NULL  NULL  NULL  NULL
# 3                      Albania          ALB     1     1     1     1     1
# 4                      Algeria          DZA     1     1     1     1     1
#
#    2013  2014  2015  2016
# 0     0     0     0     0
# 1  NULL  NULL  NULL  NULL
# ...

# %%
health = health.rename(columns = {"2008 [YR2008]" : "2008", 
                                  "2009 [YR2009]" : "2009", 
                                  "2010 [YR2010]" : "2010", 
                                  "2011 [YR2011]" : "2011", 
                                  "2012 [YR2012]" : "2012", 
                                  "2013 [YR2013]" : "2013",
                                  "2014 [YR2014]" : "2014", 
                                  "2015 [YR2015]" : "2015", 
                                  "2016 [YR2016]" : "2016"})

health.head()
# Out:
#                                          Series Name     Series Code  \
# 0  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 1  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 2  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 3  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
# 4  Prevalence of stunting, height for age (% of c...  SH_STA_STNT_ZS
#
#   Country Name Country Code  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0  Afghanistan          AFG  NULL  NULL  NULL  NULL  NULL  40.4  NULL  NULL
# 1      Belgium          BEL  NULL  NULL  NULL  NULL  NULL  NULL   1.6  NULL
# 2   Bangladesh          BGD  NULL  NULL  NULL  41.3  NULL  38.7  36.2  NULL
# 3       Bhutan          BTN  34.9  NULL  33.5  NULL  NULL  NULL  NULL  NULL
# 4      Austria          AUT  NULL  NULL  NULL  NULL  NULL  NULL  NULL  NULL
#
#    2016
# 0  NULL
# 1  NULL
# 2  NULL
# 3  NULL
# 4  NULL

# %%
health.tail()
# Out:
#                                          Series Name        Series Code  \
# 105863  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105864  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105865  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105866  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
# 105867  Age population, age 00, female, interpolated  SP_POP_AG00_FE_IN
#
#               Country Name Country Code      2008      2009      2010  \
# 105863  West Bank and Gaza          PSE     60722   62009.5     63779
# 105864               World          WLD      NULL      NULL      NULL
# 105865         Yemen, Rep.          YEM  397553.5  404589.5  411671.5
# 105866              Zambia          ZMB    260300  266607.5    272723
# 105867            Zimbabwe          ZWE    209359  217235.5    224492
#
#             2011      2012      2013      2014      2015      2016
# ...

# %%
jobs = pd.read_excel(jobs_path)

# %%
jobs.tail()
# Out:
#                    Country Name Country Code Series Name Series Code  \
# 40172                       NaN          NaN         NaN         NaN
# 40173                       NaN          NaN         NaN         NaN
# 40174                       NaN          NaN         NaN         NaN
# 40175  Data from database: Jobs          NaN         NaN         NaN
# 40176  Last Updated: 06/29/2022          NaN         NaN         NaN
#
#       2008 [YR2008] 2009 [YR2009] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 40172           NaN           NaN           NaN           NaN           NaN
# 40173           NaN           NaN           NaN           NaN           NaN
# 40174           NaN           NaN           NaN           NaN           NaN
# 40175           NaN           NaN           NaN           NaN           NaN
# 40176           NaN           NaN           NaN           NaN           NaN
#
#       2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]
# ...

# %%
jobs = jobs.drop([40172, 40173, 40174, 40175, 40176])
jobs = jobs.replace("..", "NULL")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 jobs = jobs.drop([40172, 40173, 40174, 40175, 40176])
#       2 jobs = jobs.replace("..", "NULL")
#
# File D:\anaconda3\envs\cis5500\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\anaconda3\envs\cis5500\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
jobs.tail()
# Out:
#       Country Name Country Code  \
# 40167     Zimbabwe          ZWE
# 40168     Zimbabwe          ZWE
# 40169     Zimbabwe          ZWE
# 40170     Zimbabwe          ZWE
# 40171     Zimbabwe          ZWE
#
#                                              Series Name        Series Code  \
# 40167  Vulnerable employment, male (% of male employm...  SL_EMP_VULN_MA_ZS
# 40168  Vulnerable employment, total (% of total emplo...     SL_EMP_VULN_ZS
# 40169  Wage and salaried workers, female (% of female...  SL_EMP_WORK_FE_ZS
# 40170  Wage and salaried workers, male (% of male emp...  SL_EMP_WORK_MA_ZS
# 40171  Wage and salaried workers, total (% of total e...     SL_EMP_WORK_ZS
#
#       2008 [YR2008] 2009 [YR2009] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 40167        59.716        59.904     59.256998     57.928001     56.639999
# 40168        71.458     69.369001        68.192     66.808999     65.864998
# 40169        15.266        20.278        22.111        23.546        24.135
# ...

# %%
jobs = jobs.rename(columns = {"2008 [YR2008]" : "2008", 
                                  "2009 [YR2009]" : "2009", 
                                  "2010 [YR2010]" : "2010", 
                                  "2011 [YR2011]" : "2011", 
                                  "2012 [YR2012]" : "2012", 
                                  "2013 [YR2013]" : "2013",
                                  "2014 [YR2014]" : "2014", 
                                  "2015 [YR2015]" : "2015", 
                                  "2016 [YR2016]" : "2016"})

# %%
jobs.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0            Access to electricity (% of population)     EG_ELC_ACCS_ZS
# 1  Adolescent fertility rate (births per 1,000 wo...        SP_ADO_TFRT
# 2  Age dependency ratio (% of working-age populat...        SP_POP_DPND
# 3                Agriculture, value added (% of GDP)     NV_AGR_TOTL_ZS
# 4         Agriculture, value added (annual % growth)  NV_AGR_TOTL_KD_ZG
#
#          2008        2009        2010       2011       2012       2013  \
# 0        42.4   44.854885        42.7  43.222019       69.1  67.259552
# 1    111.1414    104.8868     98.6322    92.3776     86.123    81.7908
# 2  100.656496  100.740813  100.406412  98.730759   96.52859  94.001734
# ...

# %%
jobs.tail()
# Out:
#       Country Name Country Code  \
# 40167     Zimbabwe          ZWE
# 40168     Zimbabwe          ZWE
# 40169     Zimbabwe          ZWE
# 40170     Zimbabwe          ZWE
# 40171     Zimbabwe          ZWE
#
#                                              Series Name        Series Code  \
# 40167  Vulnerable employment, male (% of male employm...  SL_EMP_VULN_MA_ZS
# 40168  Vulnerable employment, total (% of total emplo...     SL_EMP_VULN_ZS
# 40169  Wage and salaried workers, female (% of female...  SL_EMP_WORK_FE_ZS
# 40170  Wage and salaried workers, male (% of male emp...  SL_EMP_WORK_MA_ZS
# 40171  Wage and salaried workers, total (% of total e...     SL_EMP_WORK_ZS
#
#             2008       2009       2010       2011       2012       2013  \
# 40167     59.716     59.904  59.256998  57.928001  56.639999  55.434001
# 40168     71.458  69.369001     68.192  66.808999  65.864998  65.244999
# 40169     15.266     20.278     22.111     23.546     24.135     24.027
# ...

# %%
gender.to_excel("gender_clean.xlsx")

# %%
health.to_excel("health_clean.xlsx")

# %%
jobs.to_excel("jobs_clean.xlsx")
